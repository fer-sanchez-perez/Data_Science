# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl
dr=pd.read_csv(r"departamentos-nuevo.csv",dtype="string")
dr['precio'] = dr['precio'].fillna('0')
dr['precio'] = dr['precio'].apply(lambda x: x.replace('$', '').replace(',', '').replace('MN','').replace(' ','').replace('NM','')).astype(float)
dr['precio'] = dr['precio'].replace(0,np.NaN)
print("El promedio de renta de un departamento es de: $",round(dr['precio'].mean(),3))
print("la desviacion estandar de los precios de renta de un departamento es de: $",round(dr['precio'].std(),3))
#print(dr["precio"].plot(style = "o",ms = 1,xlabel="departamentos",ylabel = "precio"))
colonias=['El Refugio', 'Juriquilla,', 'Milenio', 'El Mirador','El campanario', 'Jurica', 'Centro Sur', 'Cumbres del lago', 'Candiles', 'El Pueblico']

prom_depas=[dr.loc[dr['web-scraper-start-url'].str.contains("refugio"),'precio'].mean(),
            dr.loc[dr['web-scraper-start-url'].str.contains("juriquilla"),'precio'].mean(),
            dr.loc[dr['web-scraper-start-url'].str.contains("milenio"),'precio'].mean(),
            dr.loc[dr['web-scraper-start-url'].str.contains("mirador"),'precio'].mean(),
            dr.loc[dr['web-scraper-start-url'].str.contains("campanario"),'precio'].mean(),
            dr.loc[dr['web-scraper-start-url'].str.contains("jurica"),'precio'].mean(),
            dr.loc[dr['web-scraper-start-url'].str.contains("sur"),'precio'].mean(),
            dr.loc[dr['web-scraper-start-url'].str.contains("cumbres"),'precio'].mean(),
            dr.loc[dr['web-scraper-start-url'].str.contains("candiles"),'precio'].mean(),
            dr.loc[dr['web-scraper-start-url'].str.contains("pueblito"),'precio'].mean()]
gra_precios = mpl.figure()
gra_precios.set_figheight(10)
gra_precios.set_figwidth(20)
mpl.plot(dr['precio'],'purple')

gra_prom = mpl.figure()
gra_prom.set_figheight(10)
gra_prom.set_figwidth(20)
mpl.bar(colonias,prom_depas,color='purple')

mpl.show()
# Out:
# El promedio de renta de un departamento es de: $ 18879.704
# la desviacion estandar de los precios de renta de un departamento es de: $ 8182.147

# %%
dt=pd.read_csv(r"scrap-casa-venta (2).csv",dtype="string")
dt['precio'] = dt['precio'].fillna('0')
dt['precio'] = dt['precio'].apply(lambda x: x.replace('$', '').replace(',', '').replace('MN','').replace(' ','').replace('NM','').replace('MX','')).astype(float)
dt['precio'] = dt['precio'].replace(0,np.NaN)
print("El promedio de venta de una casa es de: $",round(dt['precio'].mean(),3))
print("la desviacion estandar de los precios de venta de una casa es de: $",round(dt['precio'].std(),3))
#print(dt["precio"].plot(style = "o",ms = 1))
prom_casas=[dt.loc[dt['web-scraper-start-url'].str.contains("refugio"),'precio'].mean(),
            dt.loc[dt['web-scraper-start-url'].str.contains("juriquilla"),'precio'].mean(),
            dt.loc[dt['web-scraper-start-url'].str.contains("milenio"),'precio'].mean(),
            dt.loc[dt['web-scraper-start-url'].str.contains("mirador"),'precio'].mean(),
            dt.loc[dt['web-scraper-start-url'].str.contains("campanario"),'precio'].mean(),
            dt.loc[dt['web-scraper-start-url'].str.contains("jurica"),'precio'].mean(),
            dt.loc[dt['web-scraper-start-url'].str.contains("sur"),'precio'].mean(),
            dt.loc[dt['web-scraper-start-url'].str.contains("cumbres"),'precio'].mean(),
            dt.loc[dt['web-scraper-start-url'].str.contains("candiles"),'precio'].mean(),
            dt.loc[dt['web-scraper-start-url'].str.contains("pueblito"),'precio'].mean()]
gra_preciosC = mpl.figure()
gra_preciosC.set_figheight(10)
gra_preciosC.set_figwidth(20)
mpl.plot(dr['precio'])

gra_promC = mpl.figure()
gra_promC.set_figheight(10)
gra_promC.set_figwidth(20)
mpl.bar(colonias,prom_casas)

mpl.show()
# Out:
# El promedio de venta de una casa es de: $ 5847378.789
# la desviacion estandar de los precios de venta de una casa es de: $ 5929981.787
